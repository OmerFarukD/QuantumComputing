# %%
from qiskit import *
from qiskit.visualization import plot_histogram
# %matplotlib inline

# %%
sayi="1000101"

# %%
devre=QuantumCircuit(8,7)

# %%
devre.h([i for i in range(7)])
devre.x(7)
devre.h(7)

# %%
devre.draw(output="mpl")

# %%
devre.barrier()
devre.cx([0,2,6],7)

# %%
devre.draw(output="mpl")

# %%
devre.barrier()

# %%
devre.h([i for i in range(7)])

# %%
devre.measure([i for i in range(7)],[i for i in range(7)])

# %%
devre.draw(output="mpl")

# %%
simulator=Aer.get_backend("qasm_simulator")

# %%
simulator_job=execute(devre,backend=simulator,shots=1).result()

# %%
counts=simulator_job.get_counts()

# %%
print(counts)
# Out:
# {'1000101': 1}
